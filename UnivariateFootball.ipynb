# %% [markdown]
# <a href="https://colab.research.google.com/github/garvit968/PythonTut/blob/main/UnivariateFootball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('euro_summary.csv')

# %%
df
# Out:
#     year          winner                          final         result  \
# 0   1960            USSR              USSR - Yugoslavia          1 - 1
# 1   1964           Spain                   Spain - USSR          2 - 2
# 2   1968           Italy             Italy - Yugoslavia          2 - 2
# 3   1972    West Germany            West Germany - USSR          3 - 3
# 4   1976  Czechoslovakia  Czechoslovakia - West Germany  2 - 2 (5 - 3)
# 5   1980    West Germany         Belgium - West Germany          1 - 1
# 6   1984          France                 France - Spain          2 - 2
# 7   1988     Netherlands             USSR - Netherlands          0 - 0
# 8   1992         Denmark              Denmark - Germany          2 - 2
# 9   1996         Germany              Czechia - Germany          1 - 1
# 10  2000          France                 France - Italy          1 - 1
# 11  2004          Greece              Portugal - Greece          0 - 0
# ...

# %%
sns.countplot(df['winner'])
# Out:
# <Axes: xlabel='count', ylabel='winner'>

# %%
df['winner'].value_counts().plot(kind= 'pie',autopct='%.2f' )
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['matches'])
# Out:
# (array([5., 0., 4., 0., 0., 5., 0., 0., 0., 3.]),
#  array([ 4. ,  8.7, 13.4, 18.1, 22.8, 27.5, 32.2, 36.9, 41.6, 46.3, 51. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['attendance'])
# Out:
# <ipython-input-26-b55871d5e13d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['attendance'])
# <Axes: xlabel='attendance', ylabel='Density'>

# %%
df.describe()
# Out:
#              year    matches       goals  red_cards    attendance  \
# count    17.00000  17.000000   17.000000  17.000000  1.700000e+01
# mean   1992.00000  22.823529   55.647059   2.823529  8.991269e+05
# std      20.19901  17.161859   41.373212   2.743977  7.771803e+05
# min    1960.00000   4.000000    7.000000   0.000000  7.895800e+04
# 25%    1976.00000   5.000000   19.000000   0.000000  2.609360e+05
# 50%    1992.00000  15.000000   41.000000   3.000000  8.498440e+05
# 75%    2008.00000  31.000000   77.000000   5.000000  1.150802e+06
# max    2024.00000  51.000000  142.000000   8.000000  2.681288e+06
#
#        attendance_avg  goals_avg  red_cards_avg
# count       17.000000  17.000000      17.000000
# mean     37306.062941   2.624118       0.135882
# std      11337.587389   0.818711       0.182553
# min      19739.500000   1.400000       0.000000
# 25%      26627.500000   2.130000       0.000000
# 50%      37122.650000   2.480000       0.100000
# ...

# %%
sns.boxplot(df['attendance'])
# Out:
# <Axes: ylabel='attendance'>
